# %%
# Welcome
This is my first Jupyter Notebook an Github.

It is created with Visual Studio Code and Jupyter Notebook plugin.

# %%
# ipympl can be install via pip or conda.
# widget looks not supported on Github
#%matplotlib widget
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# Testing matplotlib interactions with a simple plot
fig = plt.figure()
plt.plot(np.sin(np.linspace(0, 20, 100)));

# %% [markdown]
# [slider example](slider.ipynb)
#
# Or open the converted html page with raw.githack.com
# [slider.html](https://raw.githack.com/AWolf81/my-first-jupyter-notebook/main/slider.html)
